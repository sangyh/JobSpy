# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["indeed", "zip_recruiter"], # "linkedin", "google", "glassdoor", "bayt", "naukri", "bdjobs"
    search_term="shipyard jobs",
    # google_search_term="software engineer jobs near San Francisco, CA since yesterday",
    # location="Pascagoula, MS, US",
    results_wanted=100,
    hours_old=900,
    country_indeed='USA',
    
    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# Found 100 jobs
#                     id    site  \
# 0  in-58b14ecd3eb7cf16  indeed
# 1  in-2b2125891b45e025  indeed
# 2  in-98754051d330b2ed  indeed
# 3  in-3e42388b82ae27d5  indeed
# 4  in-122df5693afbcb4a  indeed
#
#                                              job_url  \
# 0  https://www.indeed.com/viewjob?jk=58b14ecd3eb7...
# 1  https://www.indeed.com/viewjob?jk=2b2125891b45...
# 2  https://www.indeed.com/viewjob?jk=98754051d330...
# 3  https://www.indeed.com/viewjob?jk=3e42388b82ae...
# 4  https://www.indeed.com/viewjob?jk=122df5693afb...
#
#                                       job_url_direct  \
# 0  http://www.indeed.com/job/senior-marine-electr...
# 1  http://www.indeed.com/job/estimator-project-ma...
# 2  http://www.indeed.com/job/quality-control-insp...
# 3  http://www.indeed.com/job/quality-control-engi...
# 4  http://www.indeed.com/job/project-manager-mech...
#
#                                    title                    company  \
# 0              Senior Marine Electrician                      Serco
# 1            Estimator / Project Manager  Shipyard Military Vessels
# 2           Quality Control Inspector II                        GIS
# 3               Quality Control Engineer                        GIS
# 4  Project Manager - Mechanical Engineer                        GIS
#
#                 location date_posted            job_type salary_source  ...  \
# 0   Newport News, VA, US  2025-11-20            fulltime   direct_data  ...
# 1  National City, CA, US  2025-11-20            fulltime   direct_data  ...
# 2        Houston, TX, US  2025-11-20  fulltime, contract           NaN  ...
# 3        Houston, TX, US  2025-11-20  fulltime, contract           NaN  ...
# 4     Plaquemine, LA, US  2025-11-20            fulltime   direct_data  ...
#
#                        company_addresses  company_num_employees  \
# 0                                    NaN                10,000+
# 1                                    NaN                    NaN
# 2  18838 Hwy. 3235\r\nGalliano, LA 70354         1,001 to 5,000
# 3  18838 Hwy. 3235\r\nGalliano, LA 70354         1,001 to 5,000
# 4  18838 Hwy. 3235\r\nGalliano, LA 70354         1,001 to 5,000
#
#     company_revenue                                company_description  \
# 0  $1B to $5B (USD)  Serco is one of the world’s largest providers ...
# 1               NaN                                                NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
#    skills experience_range company_rating company_reviews_count vacancy_count  \
# 0    None             None           None                  None          None
# 1    None             None           None                  None          None
# 2    None             None           None                  None          None
# 3    None             None           None                  None          None
# 4    None             None           None                  None          None
#
#   work_from_home_type
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 34 columns]
